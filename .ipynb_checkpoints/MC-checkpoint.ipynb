# %%
include("./perov_functions.jl")
using Plots
using BenchmarkTools
using Distributions
using LaTeXStrings
using Measures

# %%
n=2;nk=100;
system_original=make_symstem(n);
system=copy(system_original);

# %%
function e1(system)
    axis=rand(Uniform(-1.,1.),3)
    theta=rand(Uniform(0,2π))
    pos=rand(1:size(system)[1],3)
    s,s1=get_rotation_energy_1(system,1,1/250,pos,axis,theta);
    if s<0
        system=s1
        end;
    e=get_total_energy_mag(system,1,1/150)
    return e
    end;

# %%
function run_sum(n,system,g1,g2)
    e=[]
    a1=[]
    a2=[]
    a3=[]
    mag_val=[]
    for i in 1:n
        axis=rand(Uniform(-1.,1.),3)
        theta=rand(Uniform(0,2π))
        pos=rand(1:size(system)[1],3)
        s,s1=get_rotation_energy_1(system,g1,g2,pos,axis,theta);
        if s<0
            system=s1
            end;
        if i%100==0
            vals=get_total_energy_mag(system,g1,g2)
            energy=vals[1]
            angles=vals[2].^2
            push!(e,energy)
            push!(a1,angles[1])
            push!(a2,angles[2])
            push!(a3,angles[3])
            push!(mag_val,norm(vals[2]))
            end;
        end;
    return e,a1,a2,a3,mag_val,system
    end;

# %%
system=copy(system_original);
@time e,a1,a2,a3,mag_val,system=run_sum(1000,system,1,1/1500);
# Out:
#   0.965332 seconds (6.04 M allocations: 626.434 MiB, 14.43% gc time)

# %%
function animplots(i)
gr()
pl1=plot((1:i)*100,e[1:i],ylabel="energy",xlabel="iterations",color=RGB(226/255, 194/255, 144/255),label="",linewidth=2)
pl2=plot((1:i)*100,a1[1:i],label=L"$s_x$",xlabel="iterations",ylabel="component",ylim=(-0.01,1.1))
plot!(pl2,(1:i)*100,a2[1:i],label=L"$s_y$")
plot!(pl2,(1:i)*100,a3[1:i],label=L"$s_z$")
pl3=plot((1:i)*100,mag_val[1:i],ylabel=L"$M$",xlabel="iterations",color=RGB(202/255, 255/255, 191/255),linewidth=2,label="",ylim=(-0.01,1.1))
plot(pl1,pl3,pl2,size=(1200,400),dpi=100,layout=@layout [a b c])
end;

# %%
anim = @animate for i ∈ 1:length(e)
    animplots(i)
end
gif(anim, "animations/MC_test.gif", fps = 17)
# Out:
# ┌ Info: Saved animation to
# │   fn = /Volumes/GoogleDrive/My Drive/github projects/Perovskite/animations/MC_test.gif
# └ @ Plots /Users/santy/.julia/packages/Plots/5srrj/src/animation.jl:104
# Plots.AnimatedGif("/Volumes/GoogleDrive/My Drive/github projects/Perovskite/animations/MC_test.gif")
